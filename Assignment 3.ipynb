# %% [markdown]
# # Assignment 3: Exploratory Data Analysis

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\patel\Downloads\dataset3 - Sheet1.csv")

# %%
df
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         1       3
# 1            2         0       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         1       2
# 7            8         0       2
# 8            9         1       1
# 9           10         0       3
#
#                                            Name     Sex  Age  SibSp  Parch  \
# 0                            Allen, Mr. William    male   35      0      0
# 1                      Bonnell, Miss. Elizabeth  female   58      0      0
# 2                   Saundercock, Mr. William H.    male   20      0      0
# 3                   Andersson, Mr. Anders Johan    male   39      1      5
# 4          Vestrom, Miss. Hulda Amanda Adolfina  female   14      0      0
# 5               Hewlett, Mrs. (Mary D Kingcome)  female   55      0      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  10 non-null     int64
#  1   Survived     10 non-null     int64
#  2   Pclass       10 non-null     int64
#  3   Name         10 non-null     object
#  4   Sex          10 non-null     object
#  5   Age          10 non-null     int64
#  6   SibSp        10 non-null     int64
#  7   Parch        10 non-null     int64
#  8   Ticket       10 non-null     object
#  9   Fare         10 non-null     float64
#  10  Cabin        3 non-null      object
#  11  Embarked     10 non-null     object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 1.1+ KB

# %%
df.describe()
# Out:
#        PassengerId   Survived     Pclass        Age      SibSp      Parch  \
# count     10.00000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean       5.50000   0.500000   2.200000  34.300000   0.600000   0.600000
# std        3.02765   0.527046   0.918937  18.505555   1.264911   1.577621
# min        1.00000   0.000000   1.000000   2.000000   0.000000   0.000000
# 25%        3.25000   0.000000   1.250000  22.500000   0.000000   0.000000
# 50%        5.50000   0.500000   2.500000  35.500000   0.000000   0.000000
# 75%        7.75000   1.000000   3.000000  50.250000   0.750000   0.000000
# max       10.00000   1.000000   3.000000  58.000000   4.000000   5.000000
#
#             Fare
# count  10.000000
# mean   24.396000
# std    17.292144
# min     7.250000
# 25%     9.287500
# 50%    21.275000
# 75%    30.740000
# max    53.100000

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          7
# Embarked       0
# dtype: int64

# %%
# Dropping Cabin column
df.drop(columns=['Cabin'], inplace=True)

# %% [markdown]
# Survival rate by gender

# %%
survival_by_gender = df.groupby('Sex')['Survived'].mean()
print(survival_by_gender)
# Out:
# Sex
# female    0.250000
# male      0.666667
# Name: Survived, dtype: float64

# %% [markdown]
# Survival rate by passenger class

# %%
survival_by_class = df.groupby('Pclass')['Survived'].mean()
print(survival_by_class)
# Out:
# Pclass
# 1    0.666667
# 2    0.500000
# 3    0.400000
# Name: Survived, dtype: float64

# %% [markdown]
# # Visualization

# %% [markdown]
# Age Distribution

# %%
sns.histplot(df['Age'], bins=8,kde = True)
plt.title('Age Distribution of Passengers')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Survival by class and gender

# %%
sns.barplot(data = df, x='Pclass', y='Survived', hue='Sex')
plt.title('Survival Rate by Class and Gender')
plt.ylabel('Survival Rate')
plt.show()

# %% [markdown]
# Correlation Heatmap

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # Summary
# - Majority of survivors in this sample were male and from 1st or 3rd class.
# - First class people has better chance of survival.
# - Age is mostly Distributed between 30 to 45.
